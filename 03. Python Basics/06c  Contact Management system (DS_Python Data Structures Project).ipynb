# %% [markdown]
# ### A simple contact management system.
#
# **This system will allow users to:**
#
# 1. Store contacts (names and phone numbers) in a list.
# 2. Add a contact to the list.
# 3. Remove a specific contact from the list.
# 4. Check if a specific contact is in the list.
# 5. Display the list of contacts.
# 6. Provide a menu to choose from the options.

# %%
# Exploring how tuples behave
t = ("name1", 9111)

t[0]

# %%
x = [('name1', 9111), ('name2', 887), ('name3', 776)]

x.pop(0)

x

# %%
contact_list = []

while True:
     # Display the menu
    print("Contact Management Menu:")
    print("1. Add a contact")
    print("2. Remove a specific contact")
    print("3. Check if a specific contact is in the list")
    print("4. Display the list")
    print("5. Quit\n\n")
    
    #Get user's choice
    choice = input("choose an option 1-5 : ")
    
    if choice == '1':
        name = input("Enter the contact name: ")
        phone = input("Enter the contact phone number: ")
        contact_list.append((name, phone))
        print(f"Contact '{name}' added to the list.")
    
    elif choice == '2':
        name = input("Enter name to be removed ")
        for i, j in enumerate (contact_list):
            if name == j[0]:
                contact_list.pop(i)
                print(f"{name} successfully removed from contact list")
                
    elif choice == '3':
        name = input("Enter name: ")
        for i in (contact_list):
            if name == i[0]:
                print(f"{name} is in the contact list")
            else:
                print("name not found")
    
    elif choice == '4':        
        if contact_list:
            for i, (name, phone) in enumerate(contact_list, 1):
                print(f'{i}. {name}: {phone}')
        else:
            print('Contact list is empty')
    
    elif choice == '5':
        print("Closing the program... Bye")
        break
    
    else:
        print("Invalid choice. Please enter a valid option")

# %%
## Initialize the contact list (an empty list)
contact_list = []

while True:
    # Display the menu
    print("Contact Management Menu:")
    print("1. Add a contact")
    print("2. Remove a specific contact")
    print("3. Check if a specific contact is in the list")
    print("4. Display the list")
    print("5. Quit")
    
    # Get user choice
    choice = input("Choose an option (1-5): ")
    
    if choice == '1':
        # Add a contact
        name = input("Enter the contact name: ")
        phone = input("Enter the contact phone number: ")
        contact_list.append((name, phone))  # Add the contact as a tuple (a data type in Python)
        print(f"Contact '{name}' added to the list.")
    
    elif choice == '2':
        # Remove a specific contact
        name = input("Enter the contact name to remove: ")
        for i, j in enumerate(contact_list):
            if contact_list[i][0] == name:
                contact_list.pop(i) # Remove the contact from the list
                print(f"{name} has been removed from the list")
                
    elif choice == '3':
        # Check if a specific contact is in the list
        name = input("Enter the contact name to check: ")
        # Find the contact by name
        for c in contact_list:  
            if c[0] == name:
                print(f"{name} is in the list")
            else:
                print(f"{name} isn't in the list")
    
    elif choice == '4':
        # Display the list
        if contact_list:
            print("Contact List:")
            for i, (name, phone) in enumerate(contact_list, 1): # Enumerate through the contact list starting from 1 instead of 0
                print(f"{i}. {name}: {phone}")
        else:
            print("The list is empty.")
    
    elif choice == '5':
        # Quit the program
        print("Quitting the program. Goodbye!")
        break
    
    else:
        # Handle invalid input
        print("Invalid choice. Please choose a valid option.")

# %% [markdown]
# ---
# _**Your Dataness**_,
# `Obinna Oliseneku` (_**Hybraid**_)
# **[LinkedIn](https://www.linkedin.com/in/obinnao/)** | **[GitHub](https://github.com/hybraid6)**
